# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#概要" data-toc-modified-id="概要-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>概要</a></span></li><li><span><a href="#誰のための記事？" data-toc-modified-id="誰のための記事？-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>誰のための記事？</a></span></li><li><span><a href="#課題内容" data-toc-modified-id="課題内容-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>課題内容</a></span><ul class="toc-item"><li><span><a href="#実現したいこと" data-toc-modified-id="実現したいこと-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>実現したいこと</a></span></li><li><span><a href="#前提" data-toc-modified-id="前提-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>前提</a></span></li><li><span><a href="#普通にソートすることによる問題" data-toc-modified-id="普通にソートすることによる問題-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>普通にソートすることによる問題</a></span></li><li><span><a href="#解決方法" data-toc-modified-id="解決方法-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>解決方法</a></span></li><li><span><a href="#この課題で扱わないこと" data-toc-modified-id="この課題で扱わないこと-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>この課題で扱わないこと</a></span></li></ul></li><li><span><a href="#ダミーデータの準備" data-toc-modified-id="ダミーデータの準備-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>ダミーデータの準備</a></span></li><li><span><a href="#PyMCでモデルを組む" data-toc-modified-id="PyMCでモデルを組む-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>PyMCでモデルを組む</a></span><ul class="toc-item"><li><span><a href="#ステップ概要" data-toc-modified-id="ステップ概要-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>ステップ概要</a></span><ul class="toc-item"><li><span><a href="#確率変数や事前分布などをどうするのか決める。" data-toc-modified-id="確率変数や事前分布などをどうするのか決める。-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>確率変数や事前分布などをどうするのか決める。</a></span></li></ul></li><li><span><a href="#モデルを組む" data-toc-modified-id="モデルを組む-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>モデルを組む</a></span></li><li><span><a href="#モデルの確認" data-toc-modified-id="モデルの確認-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>モデルの確認</a></span><ul class="toc-item"><li><span><a href="#レビューが少ないケース" data-toc-modified-id="レビューが少ないケース-5.3.1"><span class="toc-item-num">5.3.1&nbsp;&nbsp;</span>レビューが少ないケース</a></span></li><li><span><a href="#レビューが多いケース" data-toc-modified-id="レビューが多いケース-5.3.2"><span class="toc-item-num">5.3.2&nbsp;&nbsp;</span>レビューが多いケース</a></span></li></ul></li></ul></li><li><span><a href="#全商品の95％信用下限値の算出" data-toc-modified-id="全商品の95％信用下限値の算出-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>全商品の95％信用下限値の算出</a></span></li><li><span><a href="#ソート" data-toc-modified-id="ソート-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>ソート</a></span></li><li><span><a href="#Appendix" data-toc-modified-id="Appendix-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Appendix</a></span></li><li><span><a href="#環境" data-toc-modified-id="環境-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>環境</a></span><ul class="toc-item"><li><span><a href="#ノート環境" data-toc-modified-id="ノート環境-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>ノート環境</a></span></li><li><span><a href="#Python-環境" data-toc-modified-id="Python-環境-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Python 環境</a></span></li><li><span><a href="#ライブラリ環境" data-toc-modified-id="ライブラリ環境-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>ライブラリ環境</a></span></li></ul></li></ul></div>

# %% [markdown]
# # 概要
#
# - [Pythonで体験するベイズ推論 PyMCによるMCMC入門](https://www.amazon.co.jp/Python%E3%81%A7%E4%BD%93%E9%A8%93%E3%81%99%E3%82%8B%E3%83%99%E3%82%A4%E3%82%BA%E6%8E%A8%E8%AB%96-PyMC%E3%81%AB%E3%82%88%E3%82%8BMCMC%E5%85%A5%E9%96%80-%E3%82%AD%E3%83%A3%E3%83%A1%E3%83%AD%E3%83%B3-%E3%83%87%E3%83%93%E3%83%83%E3%83%89%E3%82%BD%E3%83%B3-%E3%83%94%E3%83%AD%E3%83%B3/dp/4627077912/)の書籍を結構前に読了しましたが、しばらくPyMCを触っていないので、復習用に自習課題として動かします。
# - どんな書籍なのか、というのはここでは触れないので、[『Pythonで体験するベイズ推論 ―PyMCによるMCMC入門―』の書評](http://statmodeling.hatenablog.com/entry/bayesian-methods-for-hackers-ja)などをご確認ください。（書籍自体はとても分かりやすかった・・）
# - ちなみに統計・確率・数学・ベイズ周りは初心者（理系でもない）なため、理解が浅い点はご了承ください。

# %% [markdown]
# # 誰のための記事？
#
# - 書籍が元々For hackers とあるように、書籍もエンジニア・もしくは最近PyMCを触り始めた方など向けで、この記事でもほとんど数式などは扱いません。
# - がっつりデータサイエンスを仕事にしている方達からすると、大分物足りない記事だとは思います。
# - ディープラーニングを先に学んでから、それを踏まえて比較などしつつ記事を書いています。「[ゼロから作る Deep Learning](https://www.amazon.co.jp/%E3%82%BC%E3%83%AD%E3%81%8B%E3%82%89%E4%BD%9C%E3%82%8BDeep-Learning-%E2%80%95Python%E3%81%A7%E5%AD%A6%E3%81%B6%E3%83%87%E3%82%A3%E3%83%BC%E3%83%97%E3%83%A9%E3%83%BC%E3%83%8B%E3%83%B3%E3%82%B0%E3%81%AE%E7%90%86%E8%AB%96%E3%81%A8%E5%AE%9F%E8%A3%85-%E6%96%8E%E8%97%A4-%E5%BA%B7%E6%AF%85/dp/4873117585/ref=sr_1_1?ie=UTF8&qid=1522492306&sr=8-1&keywords=%E3%82%BC%E3%83%AD%E3%81%8B%E3%82%89%E4%BD%9C%E3%82%8Bdeep+learning)」など消化済みの方だと、より分かりやすいかもしれません。

# %% [markdown]
# # 課題内容
#
# - 書籍で例題として、upvote / downvote（いいね的な、親指マークなど）のソート問題がありました。
# - また、そちらの例題での内容は、レビュー（Amazon的な）のソートとしても使えると書かれており、数式などが軽く触れられていましたが、実際にPyMCを動かして、といったところまでは書かれていなかったので、課題としてこのレビューのソート問題を扱います。

# %% [markdown]
# ## 実現したいこと
#
# - レビューが絡む要素（商品だったり、映画だったり、etc）のおすすめ順的なもののためのソートを実現する。

# %% [markdown]
# ## 前提
#
# - ☆1～☆5までの範囲で、ユーザーが商品に対してレビューを投稿できるようなサービス。

# %% [markdown]
# ## 普通にソートすることによる問題
#
# 単純に、評価の高い順でソートすると、以下のような問題が出てくる。
#
# - ☆5.0、レビュー数1・2件程度の商品が先頭に出てくる。
# - 本当はユーザーからすると、☆4.8とかのレビューが50件程度ある要素にアクセスしたいと思われるため、できればそういった「本当に評価が高いと思われる」要素が先頭になるようにソートをしたい。
#     - 直観的にも、☆5.0でレビューが1件しかない要素よりも、☆4.8でレビューが50件程度ある要素のほうが魅力的に感じる（Amazonの商品選択時などでも、そういった商品を自然と選んでいる）。

# %% [markdown]
# ## 解決方法
#
# - PyMCを使います。
# - 書籍と同様に、MCMCでの処理後、レビュー内容的に「良い商品である可能性が高い」という商品が先頭に来るようにします。
#     - 結果としてレビュー平均値が高く、且つレビュー数が多い（＝平均値が真の値である確率が高い）商品が優遇されるようになります。
#     - レビュー数が多い方が確率が高くなる、というのはサイコロを多く振った方が各面が出る確率が真の値に近づいていくことをイメージすると分かりやすい・・かもしれません。
# - ソート自体はスカラー値で扱う必要があります。ここでは、書籍と同様、95％信用下限（後で触れます）を使います。

# %% [markdown]
# ## この課題で扱わないこと
#
# - 計算をより短時間で終わらす（webサービスなどで大量にリクエストをさばくケースなどための）ための計算の近似などは、書籍では扱われていたものの色々数式の話など必要になるのでここでは省略します。
# - 古い商品の方が、レビュー数が多くなりやすく有利になる、という点も書籍で触れられていましたが、この記事では話をシンプルにするために触れません。

# %% [markdown]
# # ダミーデータの準備
#
# 課題で使うための、ダミーデータを乱数などで用意します。
#
# - 200件の商品データを想定。
# - ID、レビュー数、レビュー比率（1.0～5.0）のカラムのデータフレームで扱います。

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
sns.set_style(style='darkgrid')

# %%
product_df = pd.DataFrame(
    columns=['id', 'review_num', 'review_rate'],
    index=np.arange(0, 200))

# %%
product_df.id = product_df.index + 1

# %%
review_num_arr = np.random.lognormal(
    mean=2, size=(200,)) + 1

# %%
product_df.review_num = review_num_arr

# %%
product_df.review_num = product_df.review_num.astype(np.int, copy=False)

# %%
product_df.review_rate = np.random.uniform(
    low=1.0, high=5.0, size=(200,))

# %%
product_df[:10]
# Out:
#    id  review_num  review_rate
# 0   1          29     1.171052
# 1   2           8     4.512538
# 2   3          12     4.310933
# 3   4          17     1.410750
# 4   5          37     3.264369
# 5   6           3     4.899745
# 6   7           7     2.256719
# 7   8           1     2.349467
# 8   9           1     4.490342
# 9  10           5     1.742555

# %%
product_df[190:200]
# Out:
#       id  review_num  review_rate
# 190  191          14     2.171503
# 191  192           5     4.223269
# 192  193          29     1.224605
# 193  194           3     2.388260
# 194  195          29     2.887370
# 195  196           4     4.222529
# 196  197           3     2.737241
# 197  198          16     2.229572
# 198  199          22     1.797979
# 199  200           5     4.863885

# %% [markdown]
# レビュー数に関しては、少ない商品の方が多いだろう・・ということで以下にようになっています。

# %%
product_df.plot(
    x='review_rate', y='review_num', kind='hist', bins=15)

# %%
product_df.review_num.min()
# Out:
# 1

# %%
product_df.review_num.max()
# Out:
# 111

# %%
# 生成したデータを保存。
product_df.to_csv(
    './20180331_ベイズ推論_レビューソート問題_ダミーデータ.csv',
    index=False, encoding='utf-8')

# %%
# 作業再開用。以前保存したデータを読み込む。
product_df = pd.read_csv('./20180331_ベイズ推論_レビューソート問題_ダミーデータ.csv')

# %% [markdown]
# # PyMCでモデルを組む
#
# モデル自体はそこまで複雑にならないものの、説明を結構飛ばすため、分かりづらい点などはご了承ください。（詳しくは書籍を・・）
#
# ## ステップ概要
#
# PyMCを扱う上で、いくつかのステップがあります。
#
# ### 確率変数や事前分布などをどうするのか決める。
#
# どのような変数が必要になるのかを決定します。
#
# ディープラーニングでいうところの入力値（画像認識であれば画像のテンソルなど）的なところになります。
#
# 今回は、レビュー数とレビューの平均値が変数となります。
#
# また、事前分布と事後分布という単語が出てきます。事前分布は単純に一様分布を扱うこともあれば、信念（きっと結果は〇〇以下にはならない筈だ、専門家は大体××と考えている）に基づいて初期分布が与えることもできます。（もしくは、別のベイズモデルの結果の分布を与えたりすることもあるようです。（StackGANっぽい））
#
# 一様分布のほうが客観的な処理となるのに比べ、事前分布になんらかの信念を与えたほうが真の値に近づくこともあります。逆に信念を与えることによって、結果にバイアスがかかり真の値からずれることもある、と言われています。どうすのかはケースバイケースで選択する必要がある、といったようなことが書籍では書かれています。
#
# ディープラーニングでの敵対的生成モデル（GANs）などでいうと、一様分布を与えるのが普通のGANsモデルで、何らかの画像を生み出したりするのに対し、信念を与えるのは条件付き生成モデル（cGAN）とかに近く、たとえば線画を与えて、その線画に収まる形でコントロールされた状態で着色をしたり、といったものに近いかなあ・・と感じています。
#
# 今回は、レビュー評価に対して、一様分布を用いて進めます。

# %% [markdown]
# Youtubeだったりの単純なプラス評価とマイナス評価であれば二項分布（Binomialクラス）を与えますが、今回はレビュー評価が1.0～5.0の範囲の、連続型確率変数となります。
#
# 分かりやすいように、以下のように各レビューの値を0.0～1.0の範囲になるように定義します。
#
# - $レビュー評価_{1.0} = 0$
# - $レビュー評価_{2.0} = 0.25$
# - $レビュー評価_{3.0} = 0.5$
# - $レビュー評価_{4.0} = 0.75$
# - $レビュー評価_{5.0} = 1$

# %% [markdown]
# 0～1の範囲の連続型確率変数ということで、ベータ分布（Betaクラス）を使います。
#
# このあたりの分布の話は、書籍だったり、[PyMCの初歩](http://wcs.hatenablog.com/entry/2017/05/28/222658)の記事で詳しく書かれています。一部、上記記事から引用させていただきます。
#
# > $\theta$は0から1までの連続値であり、特に事前の情報を持たないので、 0から1までのすべてが等確率（密度）となる事前分布を使う。 これは具体的にはパラメタ$\alpha$と$\beta$がそれぞれ1のベータ分布である。
# http://wcs.hatenablog.com/entry/2017/05/28/222658

# %% [markdown]
# 上記のような条件で、商品1件分の事後分布を取得するスクリプトを考えてみます。（PyMCの基礎 の記事も参考にします）
#
# このステップは、ディープラーニングでいうところの、学習中のステップに近いと言えます。
#
# MCMC（マルコフ連鎖モンテカルロ法）の記述が出てきます。1ステップごとに前の結果を踏まえて次の探索を行う、といった処理になります。ディープラーニングで、前の結果を踏まえて、次のエポックの学習に移るのに似ています。
#
# なお、その探索の移り変わりは、軌跡（trace）と呼ばれます。

# %% [markdown]
# ## モデルを組む

# %%
import pymc as pm

# %%
def get_posterior_review_rate_trace(review_rate, review_num):
    """
    レビュー評価の事後分布の軌跡を取得する。
    
    Parameters
    ------------
    review_rate : float
        対象の商品の1.0 ～ 5.0の範囲のレビュー評価値。
    review_num : int
        対象の商品のレビュー数。
        
    Returns
    ---------
    trace : Trace
        レビュー評価の事後分布。
    """
    
    # 前述のとおり、レビューの評価は0～1の範囲の一様分布で扱うため、
    # 引数で与えられた値に対して調整を加えます。
    # name は確率変数名。軌跡にアクセスする際などに使うため、
    # 分かりやすい任意の文字列を指定します。
    _review_rate = pm.Uniform(name='review_rate', lower=0, upper=1)
    review_rate_0_to_1 = (review_rate - 1) * 0.25
    print('0～1の範囲でのレビュー評価 : ', review_rate_0_to_1)
    
    # 前述のとおり、連続確率変数のためBeta分布を使用します。
    theta = pm.Beta(name='theta', alpha=1, beta=1)
    
    # observations は事前の観測値だったり信念を加味した事前分布の値
    # （用意した確率変数など）を設定します。
    # n は回数となり、コインを投げた回数などをイメージすると分かりやすいき
    # かもしれません。この数が多いほど、結果の確信度が高まります。
    # 今回はレビュー数が該当します。
    # value は、コインを投げて何回表が出たのか、といった値になるため、
    # レビュー評価にレビュー数を乗算した値を指定しています。
    # observed は、既に事前に観測済みの値で、固定値ですよ、ということを
    # PyMCに指定している。今回、事前にレビュー評価などは分かっている（＝固定値 
    # なため、Trueを指定。
    observations = pm.Binomial(
        name='obs', n=review_num, p=theta,
        value=review_rate_0_to_1 * review_num,
        observed=True)
    
    # MAP（maximum a posterior）を使うという指定。
    # 収束に絡んだもので、基本的には使うと結果が良くなる
    # そうです。ここでは詳細な説明は省略。
    map_ = pm.MAP([theta, observations]).fit()
    
    # このあたりは、Kerasでモデルを組む時の感覚に似ている。
    model = pm.Model([theta, observations])
    mcmc = pm.MCMC(model)
    
    # MCMCの探索を行う。第一引数はサンプリング数（探索回数）。
    # ディープラーニングのエポックに近い。（1回辺りはすぐ終わるので、
    # ディープラーニングのエポックよりは数が多くなる）
    # 第二引数はバーンインと呼ばれ、ごの件数分はサンプリング結果が破棄
    # される。今回は5000件目～20000件目のサンプリング結果が取得される。
    # ディープラーニングで最初の方のエポックは安定感がない（精度の低い
    # 結果になる）のと同様、MCMCでも最初の方は収束しておらず好ましく
    # ない値になるので、一定数破棄する。
    mcmc.sample(20000, 5000)
    
    # 探索結果のthetaの確率変数の軌跡を取得する。
    trace = mcmc.trace('theta')
    return trace

# %% [markdown]
# ## モデルの確認

# %% [markdown]
# 組んだモデルが妥当かとうか、値を直接指定してみて結果を確認してみます。
#
# 事後分布がどんな感じになったのかの確認として、さくっと確認するためのPyMCのmatplotlibのラッパー的なモジュールが用意されているのでそちらを利用します。
#
# matplotlibのpltと名称が被らないように、mcplotという名前で扱います。
#
# 取得した軌跡を引数に渡すだけで、事後分布がどのように分布になっているのかや95％信用区間を表示してくれます。

# %%
from pymc.Matplot import plot as mcplot

# %% [markdown]
# レビュー評価は4.5でそれぞれ実施。

# %% [markdown]
# ### レビューが少ないケース

# %%
trace_of_review_num_2 = get_posterior_review_rate_trace(
    review_rate=4.5, review_num=2)
# Out:
# 0～1の範囲でのレビュー評価 :  0.875
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.5 sec

# %%
mcplot(trace_of_review_num_2)
# Out:
# Plotting theta

# %% [markdown]
# 右側が事後分布となります。
#
# レビュー件数が裾野の広い事後分布となりました。件数が少ないので、値の正確度が低い（＝結構ばらつく）という結果になっています。また、真の値とも大分差が開いていることがわかります。

# %% [markdown]
# ### レビューが多いケース

# %%
trace_of_review_num_50 = get_posterior_review_rate_trace(review_rate=4.5, review_num=50)
# Out:
# 0～1の範囲でのレビュー評価 :  0.875
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec

# %%
mcplot(trace_of_review_num_50)
# Out:
# Plotting theta

# %% [markdown]
# 先ほどのレビュー件数が少ない結果と比べて、大分裾野が狭くなりました。また、真の値が0.85（右のプロットの濃い縦線）辺りにあり、レビュー4.5の変換後の値0.875に近い値となっています。
#
# レビュー件数が増えたことで、「この商品はそれなりに高い確率で0.85付近の評価が妥当そうだ」とか、95％信用区間（右のプロットの薄い縦の点線）的に「ほぼほぼの確率で0.75～0.93辺りのレビュー評価だろう」といったことが判断できます。

# %% [markdown]
# この95％信用下限（左側の縦の点線）の値を使い、ソートを行います。レビュー数が多いほど裾野が狭くなり、95％信用下限が高い値になる（＝ソートで有利に判定される）結果となります。

# %% [markdown]
# # 全商品の95％信用下限値の算出
#
# 組んだモデルを反映していきます。

# %%
def get_lower_limit(trace):
    """
    対象の軌跡の95％信用下限を取得する。
    
    Parameters
    ------------
    trace : Trace
        対象の商品のMCMCの軌跡。
        
    Returns
    --------
    lower_limit : float
        対象の軌跡の95%信用下限値。
    """
    trace_arr = trace[:]
    N = trace_arr.shape[0]
    lower_limit = np.sort(trace_arr)[int(0.05 * N)]
    return lower_limit

# %%
product_df['lower_limit'] = 0

# %%
from datetime import datetime

# %%
# 長時間かかります。
for index, sr in product_df.iterrows():
    print('\n', index + 1, '件目以降を実行中', datetime.now())
    
    review_rate = sr['review_rate']
    review_num = sr['review_num']
    
    trace = get_posterior_review_rate_trace(
        review_rate=review_rate, review_num=review_num)
    lower_limit = get_lower_limit(trace=trace)
    product_df.loc[index, 'lower_limit'] = lower_limit
# Out:
#  1 件目以降を実行中 2018-03-31 12:12:57.754823
# 0～1の範囲でのレビュー評価 :  0.0427631153543
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  2 件目以降を実行中 2018-03-31 12:12:59.675139
# 0～1の範囲でのレビュー評価 :  0.878134614511
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  3 件目以降を実行中 2018-03-31 12:13:01.425695
# 0～1の範囲でのレビュー評価 :  0.827733348954
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  4 件目以降を実行中 2018-03-31 12:13:03.129929
# 0～1の範囲でのレビュー評価 :  0.102687520849
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.2 sec
#  5 件目以降を実行中 2018-03-31 12:13:04.381385
# 0～1の範囲でのレビュー評価 :  0.566092268059
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  6 件目以降を実行中 2018-03-31 12:13:05.980884
# 0～1の範囲でのレビュー評価 :  0.974936338523
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  7 件目以降を実行中 2018-03-31 12:13:07.604248
# 0～1の範囲でのレビュー評価 :  0.314179838156
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  8 件目以降を実行中 2018-03-31 12:13:09.401683
# 0～1の範囲でのレビュー評価 :  0.337366645411
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  9 件目以降を実行中 2018-03-31 12:13:11.214282
# 0～1の範囲でのレビュー評価 :  0.872585445414
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  10 件目以降を実行中 2018-03-31 12:13:13.045189
# 0～1の範囲でのレビュー評価 :  0.185638772115
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  11 件目以降を実行中 2018-03-31 12:13:15.050374
# 0～1の範囲でのレビュー評価 :  0.328812763968
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  12 件目以降を実行中 2018-03-31 12:13:16.885259
# 0～1の範囲でのレビュー評価 :  0.598451757097
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  13 件目以降を実行中 2018-03-31 12:13:18.477725
# 0～1の範囲でのレビュー評価 :  0.477150389187
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  14 件目以降を実行中 2018-03-31 12:13:20.257466
# 0～1の範囲でのレビュー評価 :  0.0860499341727
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.3 sec
#  15 件目以降を実行中 2018-03-31 12:13:21.584912
# 0～1の範囲でのレビュー評価 :  0.297597778228
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  16 件目以降を実行中 2018-03-31 12:13:23.376824
# 0～1の範囲でのレビュー評価 :  0.75637661309
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  17 件目以降を実行中 2018-03-31 12:13:25.158803
# 0～1の範囲でのレビュー評価 :  0.549101422043
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  18 件目以降を実行中 2018-03-31 12:13:26.912319
# 0～1の範囲でのレビュー評価 :  0.676380246518
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  19 件目以降を実行中 2018-03-31 12:13:28.757378
# 0～1の範囲でのレビュー評価 :  0.663155274372
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  20 件目以降を実行中 2018-03-31 12:13:30.853002
# 0～1の範囲でのレビュー評価 :  0.489533802307
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  21 件目以降を実行中 2018-03-31 12:13:32.989743
# 0～1の範囲でのレビュー評価 :  0.32566196562
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  22 件目以降を実行中 2018-03-31 12:13:35.093770
# 0～1の範囲でのレビュー評価 :  0.351911131608
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.4 sec
#  23 件目以降を実行中 2018-03-31 12:13:37.551225
# 0～1の範囲でのレビュー評価 :  0.223357799224
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.3 sec
#  24 件目以降を実行中 2018-03-31 12:13:39.859281
# 0～1の範囲でのレビュー評価 :  0.326557874073
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.8 sec
#  25 件目以降を実行中 2018-03-31 12:13:42.722116
# 0～1の範囲でのレビュー評価 :  0.934770055943
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.6 sec
#  26 件目以降を実行中 2018-03-31 12:13:45.340342
# 0～1の範囲でのレビュー評価 :  0.0723433331302
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.3 sec
#  27 件目以降を実行中 2018-03-31 12:13:47.689652
# 0～1の範囲でのレビュー評価 :  0.765027700061
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.4 sec
#  28 件目以降を実行中 2018-03-31 12:13:50.130472
# 0～1の範囲でのレビュー評価 :  0.155145855472
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.9 sec
#  29 件目以降を実行中 2018-03-31 12:13:53.287972
# 0～1の範囲でのレビュー評価 :  0.613629644828
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.3 sec
#  30 件目以降を実行中 2018-03-31 12:13:55.580858
# 0～1の範囲でのレビュー評価 :  0.816340297971
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.2 sec
#  31 件目以降を実行中 2018-03-31 12:13:57.777557
# 0～1の範囲でのレビュー評価 :  0.597877485694
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.2 sec
#  32 件目以降を実行中 2018-03-31 12:13:59.956209
# 0～1の範囲でのレビュー評価 :  0.07734607614
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  33 件目以降を実行中 2018-03-31 12:14:02.081626
# 0～1の範囲でのレビュー評価 :  0.848149535687
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  34 件目以降を実行中 2018-03-31 12:14:03.774322
# 0～1の範囲でのレビュー評価 :  0.611438930687
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  35 件目以降を実行中 2018-03-31 12:14:05.540425
# 0～1の範囲でのレビュー評価 :  0.754256085868
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  36 件目以降を実行中 2018-03-31 12:14:07.259963
# 0～1の範囲でのレビュー評価 :  0.0225023304726
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  37 件目以降を実行中 2018-03-31 12:14:09.241290
# 0～1の範囲でのレビュー評価 :  0.256037631038
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  38 件目以降を実行中 2018-03-31 12:14:11.064280
# 0～1の範囲でのレビュー評価 :  0.613828694367
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  39 件目以降を実行中 2018-03-31 12:14:12.773672
# 0～1の範囲でのレビュー評価 :  0.44990888265
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.3 sec
#  40 件目以降を実行中 2018-03-31 12:14:15.134747
# 0～1の範囲でのレビュー評価 :  0.719178722842
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  41 件目以降を実行中 2018-03-31 12:14:17.177274
# 0～1の範囲でのレビュー評価 :  0.712702133857
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  42 件目以降を実行中 2018-03-31 12:14:18.800291
# 0～1の範囲でのレビュー評価 :  0.676693010584
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  43 件目以降を実行中 2018-03-31 12:14:20.679357
# 0～1の範囲でのレビュー評価 :  0.972074829312
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  44 件目以降を実行中 2018-03-31 12:14:22.412363
# 0～1の範囲でのレビュー評価 :  0.339173332739
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  45 件目以降を実行中 2018-03-31 12:14:24.157373
# 0～1の範囲でのレビュー評価 :  0.484635154042
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.4 sec
#  46 件目以降を実行中 2018-03-31 12:14:25.616375
# 0～1の範囲でのレビュー評価 :  0.496654158766
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  47 件目以降を実行中 2018-03-31 12:14:27.378731
# 0～1の範囲でのレビュー評価 :  0.00551654078168
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  48 件目以降を実行中 2018-03-31 12:14:29.181958
# 0～1の範囲でのレビュー評価 :  0.0539647728037
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  49 件目以降を実行中 2018-03-31 12:14:30.982286
# 0～1の範囲でのレビュー評価 :  0.284941411905
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  50 件目以降を実行中 2018-03-31 12:14:32.935275
# 0～1の範囲でのレビュー評価 :  0.15293070337
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  51 件目以降を実行中 2018-03-31 12:14:34.955337
# 0～1の範囲でのレビュー評価 :  0.342978102302
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.4 sec
#  52 件目以降を実行中 2018-03-31 12:14:36.332461
# 0～1の範囲でのレビュー評価 :  0.695479027697
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  53 件目以降を実行中 2018-03-31 12:14:38.028398
# 0～1の範囲でのレビュー評価 :  0.715395673824
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  54 件目以降を実行中 2018-03-31 12:14:39.813126
# 0～1の範囲でのレビュー評価 :  0.437386499024
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  55 件目以降を実行中 2018-03-31 12:14:41.618372
# 0～1の範囲でのレビュー評価 :  0.00803780531588
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  56 件目以降を実行中 2018-03-31 12:14:43.313631
# 0～1の範囲でのレビュー評価 :  0.964177555591
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  57 件目以降を実行中 2018-03-31 12:14:44.951106
# 0～1の範囲でのレビュー評価 :  0.356700787255
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.4 sec
#  58 件目以降を実行中 2018-03-31 12:14:46.350394
# 0～1の範囲でのレビュー評価 :  0.5452422303
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  59 件目以降を実行中 2018-03-31 12:14:47.984254
# 0～1の範囲でのレビュー評価 :  0.608163906448
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.5 sec
#  60 件目以降を実行中 2018-03-31 12:14:49.586916
# 0～1の範囲でのレビュー評価 :  0.121322580187
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  61 件目以降を実行中 2018-03-31 12:14:51.416160
# 0～1の範囲でのレビュー評価 :  0.159921714315
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  62 件目以降を実行中 2018-03-31 12:14:53.515626
# 0～1の範囲でのレビュー評価 :  0.0171304506208
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  63 件目以降を実行中 2018-03-31 12:14:55.425194
# 0～1の範囲でのレビュー評価 :  0.173708391898
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  64 件目以降を実行中 2018-03-31 12:14:57.118398
# 0～1の範囲でのレビュー評価 :  0.678263709859
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  65 件目以降を実行中 2018-03-31 12:14:59.023568
# 0～1の範囲でのレビュー評価 :  0.222542824886
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  66 件目以降を実行中 2018-03-31 12:15:00.862755
# 0～1の範囲でのレビュー評価 :  0.529403797084
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  67 件目以降を実行中 2018-03-31 12:15:02.645211
# 0～1の範囲でのレビュー評価 :  0.440889304464
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  68 件目以降を実行中 2018-03-31 12:15:04.400045
# 0～1の範囲でのレビュー評価 :  0.688192496833
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  69 件目以降を実行中 2018-03-31 12:15:06.128158
# 0～1の範囲でのレビュー評価 :  0.932836915781
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  70 件目以降を実行中 2018-03-31 12:15:07.786654
# 0～1の範囲でのレビュー評価 :  0.0166777424585
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  71 件目以降を実行中 2018-03-31 12:15:09.407419
# 0～1の範囲でのレビュー評価 :  0.706942340143
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  72 件目以降を実行中 2018-03-31 12:15:11.068492
# 0～1の範囲でのレビュー評価 :  0.478179177788
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  73 件目以降を実行中 2018-03-31 12:15:12.810368
# 0～1の範囲でのレビュー評価 :  0.461945527225
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  74 件目以降を実行中 2018-03-31 12:15:14.535933
# 0～1の範囲でのレビュー評価 :  0.781098701518
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.5 sec
#  75 件目以降を実行中 2018-03-31 12:15:16.055665
# 0～1の範囲でのレビュー評価 :  0.575434162808
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  76 件目以降を実行中 2018-03-31 12:15:17.785858
# 0～1の範囲でのレビュー評価 :  0.084600631155
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  77 件目以降を実行中 2018-03-31 12:15:19.666621
# 0～1の範囲でのレビュー評価 :  0.678280297139
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  78 件目以降を実行中 2018-03-31 12:15:21.401215
# 0～1の範囲でのレビュー評価 :  0.971915438168
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  79 件目以降を実行中 2018-03-31 12:15:23.207434
# 0～1の範囲でのレビュー評価 :  0.838169907099
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.2 sec
#  80 件目以降を実行中 2018-03-31 12:15:24.474627
# 0～1の範囲でのレビュー評価 :  0.792520306068
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.0 sec
#  81 件目以降を実行中 2018-03-31 12:15:25.477970
# 0～1の範囲でのレビュー評価 :  0.576514435346
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.5 sec
#  82 件目以降を実行中 2018-03-31 12:15:26.997866
# 0～1の範囲でのレビュー評価 :  0.790324344837
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  83 件目以降を実行中 2018-03-31 12:15:28.568438
# 0～1の範囲でのレビュー評価 :  0.234172826164
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  84 件目以降を実行中 2018-03-31 12:15:30.418684
# 0～1の範囲でのレビュー評価 :  0.179761792628
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.4 sec
#  85 件目以降を実行中 2018-03-31 12:15:31.847326
# 0～1の範囲でのレビュー評価 :  0.759699247817
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.3 sec
#  86 件目以降を実行中 2018-03-31 12:15:33.141613
# 0～1の範囲でのレビュー評価 :  0.377921322229
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  87 件目以降を実行中 2018-03-31 12:15:35.039642
# 0～1の範囲でのレビュー評価 :  0.362243494693
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  88 件目以降を実行中 2018-03-31 12:15:37.060414
# 0～1の範囲でのレビュー評価 :  0.439208435459
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  89 件目以降を実行中 2018-03-31 12:15:38.829318
# 0～1の範囲でのレビュー評価 :  0.521305700832
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  90 件目以降を実行中 2018-03-31 12:15:40.652714
# 0～1の範囲でのレビュー評価 :  0.643923962654
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  91 件目以降を実行中 2018-03-31 12:15:42.437148
# 0～1の範囲でのレビュー評価 :  0.728435023832
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  92 件目以降を実行中 2018-03-31 12:15:44.413585
# 0～1の範囲でのレビュー評価 :  0.340330314282
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  93 件目以降を実行中 2018-03-31 12:15:46.106415
# 0～1の範囲でのレビュー評価 :  0.975815506522
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  94 件目以降を実行中 2018-03-31 12:15:47.740850
# 0～1の範囲でのレビュー評価 :  0.461699441644
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  95 件目以降を実行中 2018-03-31 12:15:49.527257
# 0～1の範囲でのレビュー評価 :  0.682217519569
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  96 件目以降を実行中 2018-03-31 12:15:51.183468
# 0～1の範囲でのレビュー評価 :  0.328088182855
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  97 件目以降を実行中 2018-03-31 12:15:53.127378
# 0～1の範囲でのレビュー評価 :  0.269675409595
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  98 件目以降を実行中 2018-03-31 12:15:54.938738
# 0～1の範囲でのレビュー評価 :  0.476050676434
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  99 件目以降を実行中 2018-03-31 12:15:56.531366
# 0～1の範囲でのレビュー評価 :  0.421085472129
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.5 sec
#  100 件目以降を実行中 2018-03-31 12:15:58.056789
# 0～1の範囲でのレビュー評価 :  0.448444217419
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.2 sec
#  101 件目以降を実行中 2018-03-31 12:15:59.225033
# 0～1の範囲でのレビュー評価 :  0.595646403448
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  102 件目以降を実行中 2018-03-31 12:16:00.968050
# 0～1の範囲でのレビュー評価 :  0.909796143212
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.4 sec
#  103 件目以降を実行中 2018-03-31 12:16:02.365055
# 0～1の範囲でのレビュー評価 :  0.923461583688
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.4 sec
#  104 件目以降を実行中 2018-03-31 12:16:03.788451
# 0～1の範囲でのレビュー評価 :  0.0542121341976
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  105 件目以降を実行中 2018-03-31 12:16:05.776042
# 0～1の範囲でのレビュー評価 :  0.653374042704
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  106 件目以降を実行中 2018-03-31 12:16:07.672964
# 0～1の範囲でのレビュー評価 :  0.320085245452
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.5 sec
#  107 件目以降を実行中 2018-03-31 12:16:09.273445
# 0～1の範囲でのレビュー評価 :  0.537122285386
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  108 件目以降を実行中 2018-03-31 12:16:11.033412
# 0～1の範囲でのレビュー評価 :  0.854836302884
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  109 件目以降を実行中 2018-03-31 12:16:12.700664
# 0～1の範囲でのレビュー評価 :  0.472494192415
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  110 件目以降を実行中 2018-03-31 12:16:14.481150
# 0～1の範囲でのレビュー評価 :  0.240505594283
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  111 件目以降を実行中 2018-03-31 12:16:16.283507
# 0～1の範囲でのレビュー評価 :  0.885094031179
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  112 件目以降を実行中 2018-03-31 12:16:18.111827
# 0～1の範囲でのレビュー評価 :  0.329018068539
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  113 件目以降を実行中 2018-03-31 12:16:20.053083
# 0～1の範囲でのレビュー評価 :  0.558008161283
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  114 件目以降を実行中 2018-03-31 12:16:22.176979
# 0～1の範囲でのレビュー評価 :  0.463832189033
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.2 sec
#  115 件目以降を実行中 2018-03-31 12:16:24.429796
# 0～1の範囲でのレビュー評価 :  0.130205887416
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.3 sec
#  116 件目以降を実行中 2018-03-31 12:16:26.877432
# 0～1の範囲でのレビュー評価 :  0.611573620128
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.2 sec
#  117 件目以降を実行中 2018-03-31 12:16:29.073976
# 0～1の範囲でのレビュー評価 :  0.0605187297537
#  [-----------------100%-----------------] 20000 of 20000 complete in 3.0 sec
#  118 件目以降を実行中 2018-03-31 12:16:32.098658
# 0～1の範囲でのレビュー評価 :  0.0602715715169
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.6 sec
#  119 件目以降を実行中 2018-03-31 12:16:34.727058
# 0～1の範囲でのレビュー評価 :  0.874660410577
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.2 sec
#  120 件目以降を実行中 2018-03-31 12:16:36.961199
# 0～1の範囲でのレビュー評価 :  0.492265692774
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  121 件目以降を実行中 2018-03-31 12:16:38.803246
# 0～1の範囲でのレビュー評価 :  0.218688026412
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.2 sec
#  122 件目以降を実行中 2018-03-31 12:16:40.990696
# 0～1の範囲でのレビュー評価 :  0.685780551782
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.3 sec
#  123 件目以降を実行中 2018-03-31 12:16:43.303713
# 0～1の範囲でのレビュー評価 :  0.877956515363
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.6 sec
#  124 件目以降を実行中 2018-03-31 12:16:45.943674
# 0～1の範囲でのレビュー評価 :  0.500396837104
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.4 sec
#  125 件目以降を実行中 2018-03-31 12:16:48.404664
# 0～1の範囲でのレビュー評価 :  0.870422343235
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  126 件目以降を実行中 2018-03-31 12:16:50.102255
# 0～1の範囲でのレビュー評価 :  0.843274956187
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  127 件目以降を実行中 2018-03-31 12:16:51.900608
# 0～1の範囲でのレビュー評価 :  0.866989300257
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  128 件目以降を実行中 2018-03-31 12:16:54.050174
# 0～1の範囲でのレビュー評価 :  0.57570601892
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  129 件目以降を実行中 2018-03-31 12:16:55.923817
# 0～1の範囲でのレビュー評価 :  0.335049743287
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  130 件目以降を実行中 2018-03-31 12:16:57.850004
# 0～1の範囲でのレビュー評価 :  0.211093271754
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  131 件目以降を実行中 2018-03-31 12:16:59.744327
# 0～1の範囲でのレビュー評価 :  0.486172741223
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  132 件目以降を実行中 2018-03-31 12:17:01.895366
# 0～1の範囲でのレビュー評価 :  0.72084005971
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  133 件目以降を実行中 2018-03-31 12:17:03.750805
# 0～1の範囲でのレビュー評価 :  0.331262924728
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  134 件目以降を実行中 2018-03-31 12:17:05.703229
# 0～1の範囲でのレビュー評価 :  0.35386310565
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  135 件目以降を実行中 2018-03-31 12:17:07.718776
# 0～1の範囲でのレビュー評価 :  0.837402493801
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.4 sec
#  136 件目以降を実行中 2018-03-31 12:17:09.092334
# 0～1の範囲でのレビュー評価 :  0.372893914017
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.5 sec
#  137 件目以降を実行中 2018-03-31 12:17:10.592779
# 0～1の範囲でのレビュー評価 :  0.134733639836
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  138 件目以降を実行中 2018-03-31 12:17:12.397124
# 0～1の範囲でのレビュー評価 :  0.398060001503
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  139 件目以降を実行中 2018-03-31 12:17:14.091462
# 0～1の範囲でのレビュー評価 :  0.18691063768
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  140 件目以降を実行中 2018-03-31 12:17:15.993964
# 0～1の範囲でのレビュー評価 :  0.333858090689
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  141 件目以降を実行中 2018-03-31 12:17:17.910310
# 0～1の範囲でのレビュー評価 :  0.105330795427
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  142 件目以降を実行中 2018-03-31 12:17:19.844629
# 0～1の範囲でのレビュー評価 :  0.753518246724
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  143 件目以降を実行中 2018-03-31 12:17:21.964997
# 0～1の範囲でのレビュー評価 :  0.152062475201
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.2 sec
#  144 件目以降を実行中 2018-03-31 12:17:24.217405
# 0～1の範囲でのレビュー評価 :  0.180468347508
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  145 件目以降を実行中 2018-03-31 12:17:26.220035
# 0～1の範囲でのレビュー評価 :  0.815990719821
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  146 件目以降を実行中 2018-03-31 12:17:28.025586
# 0～1の範囲でのレビュー評価 :  0.657004640074
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  147 件目以降を実行中 2018-03-31 12:17:30.034799
# 0～1の範囲でのレビュー評価 :  0.284517215767
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  148 件目以降を実行中 2018-03-31 12:17:31.864365
# 0～1の範囲でのレビュー評価 :  0.807075843301
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  149 件目以降を実行中 2018-03-31 12:17:33.617593
# 0～1の範囲でのレビュー評価 :  0.711990372865
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.3 sec
#  150 件目以降を実行中 2018-03-31 12:17:35.918415
# 0～1の範囲でのレビュー評価 :  0.335004679987
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.2 sec
#  151 件目以降を実行中 2018-03-31 12:17:38.100350
# 0～1の範囲でのレビュー評価 :  0.984382195168
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  152 件目以降を実行中 2018-03-31 12:17:40.071160
# 0～1の範囲でのレビュー評価 :  0.226271083861
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  153 件目以降を実行中 2018-03-31 12:17:42.196507
# 0～1の範囲でのレビュー評価 :  0.72729959717
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  154 件目以降を実行中 2018-03-31 12:17:44.083005
# 0～1の範囲でのレビュー評価 :  0.994461516116
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  155 件目以降を実行中 2018-03-31 12:17:45.967733
# 0～1の範囲でのレビュー評価 :  0.563664970496
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  156 件目以降を実行中 2018-03-31 12:17:48.107051
# 0～1の範囲でのレビュー評価 :  0.692049422534
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  157 件目以降を実行中 2018-03-31 12:17:50.076855
# 0～1の範囲でのレビュー評価 :  0.0625623190804
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  158 件目以降を実行中 2018-03-31 12:17:52.095003
# 0～1の範囲でのレビュー評価 :  0.207865338692
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  159 件目以降を実行中 2018-03-31 12:17:54.131084
# 0～1の範囲でのレビュー評価 :  0.697689844243
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  160 件目以降を実行中 2018-03-31 12:17:55.894702
# 0～1の範囲でのレビュー評価 :  0.966898729816
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  161 件目以降を実行中 2018-03-31 12:17:57.650728
# 0～1の範囲でのレビュー評価 :  0.102650225866
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  162 件目以降を実行中 2018-03-31 12:17:59.575402
# 0～1の範囲でのレビュー評価 :  0.410147389067
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.4 sec
#  163 件目以降を実行中 2018-03-31 12:18:01.976095
# 0～1の範囲でのレビュー評価 :  0.43392432751
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  164 件目以降を実行中 2018-03-31 12:18:03.875653
# 0～1の範囲でのレビュー評価 :  0.451217525031
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  165 件目以降を実行中 2018-03-31 12:18:05.705245
# 0～1の範囲でのレビュー評価 :  0.0164922363943
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  166 件目以降を実行中 2018-03-31 12:18:07.793860
# 0～1の範囲でのレビュー評価 :  0.504603335306
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  167 件目以降を実行中 2018-03-31 12:18:09.552804
# 0～1の範囲でのレビュー評価 :  0.780913648292
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  168 件目以降を実行中 2018-03-31 12:18:11.513287
# 0～1の範囲でのレビュー評価 :  0.669839679333
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  169 件目以降を実行中 2018-03-31 12:18:13.618348
# 0～1の範囲でのレビュー評価 :  0.804686674919
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  170 件目以降を実行中 2018-03-31 12:18:15.727459
# 0～1の範囲でのレビュー評価 :  0.799376568468
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  171 件目以降を実行中 2018-03-31 12:18:17.622788
# 0～1の範囲でのレビュー評価 :  0.410971319148
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  172 件目以降を実行中 2018-03-31 12:18:19.685921
# 0～1の範囲でのレビュー評価 :  0.191269708548
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.2 sec
#  173 件目以降を実行中 2018-03-31 12:18:21.934858
# 0～1の範囲でのレビュー評価 :  0.784707238304
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.3 sec
#  174 件目以降を実行中 2018-03-31 12:18:24.234639
# 0～1の範囲でのレビュー評価 :  0.715604404951
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  175 件目以降を実行中 2018-03-31 12:18:26.301264
# 0～1の範囲でのレビュー評価 :  0.890451588571
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  176 件目以降を実行中 2018-03-31 12:18:28.131661
# 0～1の範囲でのレビュー評価 :  0.956220690618
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  177 件目以降を実行中 2018-03-31 12:18:29.924584
# 0～1の範囲でのレビュー評価 :  0.510980692423
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  178 件目以降を実行中 2018-03-31 12:18:31.775025
# 0～1の範囲でのレビュー評価 :  0.556600731949
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  179 件目以降を実行中 2018-03-31 12:18:33.496626
# 0～1の範囲でのレビュー評価 :  0.48162939101
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  180 件目以降を実行中 2018-03-31 12:18:35.312462
# 0～1の範囲でのレビュー評価 :  0.624290997422
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  181 件目以降を実行中 2018-03-31 12:18:37.218499
# 0～1の範囲でのレビュー評価 :  0.644832489847
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  182 件目以降を実行中 2018-03-31 12:18:39.258866
# 0～1の範囲でのレビュー評価 :  0.536697720297
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  183 件目以降を実行中 2018-03-31 12:18:41.225335
# 0～1の範囲でのレビュー評価 :  0.551152695043
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  184 件目以降を実行中 2018-03-31 12:18:43.212677
# 0～1の範囲でのレビュー評価 :  0.892779345101
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.6 sec
#  185 件目以降を実行中 2018-03-31 12:18:44.862175
# 0～1の範囲でのレビュー評価 :  0.958360932012
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  186 件目以降を実行中 2018-03-31 12:18:46.939413
# 0～1の範囲でのレビュー評価 :  0.579723687803
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.2 sec
#  187 件目以降を実行中 2018-03-31 12:18:49.156315
# 0～1の範囲でのレビュー評価 :  0.839024028832
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  188 件目以降を実行中 2018-03-31 12:18:50.940422
# 0～1の範囲でのレビュー評価 :  0.792668844917
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  189 件目以降を実行中 2018-03-31 12:18:52.805214
# 0～1の範囲でのレビュー評価 :  0.240895996743
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.2 sec
#  190 件目以降を実行中 2018-03-31 12:18:55.037753
# 0～1の範囲でのレビュー評価 :  0.18277742251
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  191 件目以降を実行中 2018-03-31 12:18:57.105994
# 0～1の範囲でのレビュー評価 :  0.292875721234
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.3 sec
#  192 件目以降を実行中 2018-03-31 12:18:59.459675
# 0～1の範囲でのレビュー評価 :  0.805817235041
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  193 件目以降を実行中 2018-03-31 12:19:01.512406
# 0～1の範囲でのレビュー評価 :  0.0561511826658
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  194 件目以降を実行中 2018-03-31 12:19:03.518806
# 0～1の範囲でのレビュー評価 :  0.347064994241
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.0 sec
#  195 件目以降を実行中 2018-03-31 12:19:05.534328
# 0～1の範囲でのレビュー評価 :  0.47184240949
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  196 件目以降を実行中 2018-03-31 12:19:07.655050
# 0～1の範囲でのレビュー評価 :  0.805632168219
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec
#  197 件目以降を実行中 2018-03-31 12:19:09.397910
# 0～1の範囲でのレビュー評価 :  0.43431034339
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.8 sec
#  198 件目以降を実行中 2018-03-31 12:19:11.206528
# 0～1の範囲でのレビュー評価 :  0.307393088192
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.9 sec
#  199 件目以降を実行中 2018-03-31 12:19:13.131294
# 0～1の範囲でのレビュー評価 :  0.199494670557
#  [-----------------100%-----------------] 20000 of 20000 complete in 2.1 sec
#  200 件目以降を実行中 2018-03-31 12:19:15.276740
# 0～1の範囲でのレビュー評価 :  0.965971262338
#  [-----------------100%-----------------] 20000 of 20000 complete in 1.7 sec

# %%
product_df[:5]
# Out:
#    id  review_num  review_rate  lower_limit
# 0   1          29     1.171052     0.013478
# 1   2           8     4.512538     0.574099
# 2   3          12     4.310933     0.495006
# 3   4          17     1.410750     0.019257
# 4   5          37     3.264369     0.403900

# %% [markdown]
# # ソート
#
# 各商品の95％信用下限が算出できたので、あとはソートして終了です。

# %%
product_df.sort_values(by='lower_limit', ascending=False, inplace=True)

# %%
def round_lower_limit(lower_limit):
    """
    95％信用下限の値が、桁数が多く見づらいので、浮動小数点の3桁で切り落とし
    (四捨五入)を行う。
    
    Parameters
    -------------
    lower_limit : float
        切り落とし対象の信用下限値。
    
    Returns
    ---------
    lower_limit : float
        切り落とし後の値。
    """
    return round(lower_limit, 3)

# %%
product_df.lower_limit = product_df.lower_limit.apply(round_lower_limit)

# %%
product_df[:50]
# Out:
#       id  review_num  review_rate  lower_limit
# 159  160          19     4.867595        0.776
# 125  126          44     4.373100        0.728
# 24    25          14     4.739080        0.709
# 55    56          12     4.856710        0.695
# 174  175          17     4.561806        0.689
# 102  103          12     4.693846        0.685
# 77    78          11     4.887662        0.664
# 42    43          11     4.888299        0.658
# 175  176          10     4.824883        0.644
# 126  127          18     4.467957        0.641
# 166  167          42     4.123655        0.639
# 26    27          31     4.060111        0.599
# 1      2           8     4.512538        0.574
# 153  154           8     4.977846        0.569
# 169  170          14     4.197506        0.566
# 79    80          14     4.170081        0.561
# 118  119          11     4.498642        0.553
# 144  145          14     4.263963        0.545
# 158  159          35     3.790759        0.544
# 168  169          16     4.218747        0.527
# 110  111           7     4.540376        0.520
# 187  188          15     4.170675        0.511
# 122  123           9     4.511826        0.498
# 2      3          12     4.310933        0.495
# 184  185           6     4.833444        0.486
# 124  125           6     4.481689        0.478
# 78    79           6     4.352680        0.473
# 150  151           6     4.937529        0.469
# 73    74           8     4.124395        0.462
# 63    64          15     3.713055        0.455
# 84    85           8     4.038797        0.451
# 89    90          21     3.575696        0.449
# 131  132          12     3.883360        0.430
# 148  149          14     3.847961        0.425
# 199  200           5     4.863885        0.424
# 191  192           5     4.223269        0.422
# 173  174          12     3.862418        0.418
# 134  135           5     4.349610        0.418
# 104  105          16     3.613496        0.417
# 141  142           7     4.014073        0.414
# 186  187           7     4.356096        0.413
# 29    30           7     4.265361        0.411
# 94    95          11     3.728870        0.411
# 17    18          13     3.705521        0.404
# 39    40           9     3.876715        0.404
# 4      5          37     3.264369        0.404
# 67    68          11     3.752770        0.397
# 52    53           9     3.861583        0.395
# 40    41          11     3.850809        0.395
# 93    94         111     2.846798        0.384

# %% [markdown]
# ある程度ランダムな分布に依存するため、ID2と154と行など少し気になるものの、大まかには課題としたソート結果を得ることができました。

# %% [markdown]
# # Appendix

# %% [markdown]
# # 環境

# %% [markdown]
# ## ノート環境
#
# - Azure Notebooks

# %% [markdown]
# ## Python 環境

# %%
# !python -V
# Out:
# Python 3.5.4 :: Anaconda custom (64-bit)

# %% [markdown]
# ※PyMCのインポートでエラーになり、解決策で必要そうなapt-get関係のコマンドがAzure Notebooks関係で探すのが手間だったため、Python3.6ではなく3.5をカーネルに選択。

# %% [markdown]
# ## ライブラリ環境

# %%
# !pip freeze
# Out:
# adal==0.5.0
# alabaster==0.7.10
# altair==1.2.1
# anaconda-client==1.6.5
# anaconda-navigator==1.6.9
# anaconda-project==0.8.0
# applicationinsights==0.11.1
# argcomplete==1.9.4
# arrow==0.12.1
# asn1crypto==0.22.0
# astroid==1.5.3
# astropy==2.0.2
# attrs==17.4.0
# Automat==0.6.0
# azure-batch==4.0.0
# azure-batch-extensions==1.0.1
# azure-cli==2.0.28
# azure-cli-acr==2.0.21
# azure-cli-acs==2.0.27
# azure-cli-advisor==0.1.2
# azure-cli-appservice==0.1.28
# azure-cli-backup==1.0.6
# azure-cli-batch==3.1.10
# azure-cli-batchai==0.1.5
# azure-cli-billing==0.1.7
# azure-cli-cdn==0.0.13
# azure-cli-cloud==2.0.12
# azure-cli-cognitiveservices==0.1.11
# azure-cli-command-modules-nspkg==2.0.1
# azure-cli-configure==2.0.14
# azure-cli-consumption==0.2.2
# azure-cli-container==0.1.19
# azure-cli-core==2.0.28
# azure-cli-cosmosdb==0.1.19
# azure-cli-dla==0.0.18
# azure-cli-dls==0.0.19
# azure-cli-eventgrid==0.1.10
# azure-cli-extension==0.0.9
# azure-cli-feedback==2.1.0
# azure-cli-find==0.2.8
# azure-cli-interactive==0.3.16
# azure-cli-iot==0.1.17
# azure-cli-keyvault==2.0.19
# azure-cli-lab==0.0.17
# azure-cli-monitor==0.1.2
# azure-cli-network==2.0.24
# azure-cli-nspkg==3.0.1
# azure-cli-profile==2.0.19
# azure-cli-rdbms==0.0.12
# azure-cli-redis==0.2.11
# azure-cli-reservations==0.1.1
# azure-cli-resource==2.0.24
# azure-cli-role==2.0.20
# azure-cli-servicefabric==0.0.10
# azure-cli-sql==2.0.22
# azure-cli-storage==2.0.26
# azure-cli-vm==2.0.27
# azure-common==1.1.8
# azure-datalake-store==0.0.17
# azure-graphrbac==0.31.0
# azure-keyvault==0.3.7
# azure-mgmt-advisor==0.1.0
# azure-mgmt-authorization==0.30.0
# azure-mgmt-batch==4.1.0
# azure-mgmt-batchai==0.2.0
# azure-mgmt-billing==0.1.0
# azure-mgmt-cdn==1.0.0
# azure-mgmt-cognitiveservices==1.0.0
# azure-mgmt-compute==3.1.0rc3
# azure-mgmt-consumption==2.0.0
# azure-mgmt-containerinstance==0.3.1
# azure-mgmt-containerregistry==1.0.1
# azure-mgmt-containerservice==3.0.1
# azure-mgmt-cosmosdb==0.3.1
# azure-mgmt-datalake-analytics==0.2.0
# azure-mgmt-datalake-nspkg==2.0.0
# azure-mgmt-datalake-store==0.2.0
# azure-mgmt-devtestlabs==2.0.0
# azure-mgmt-dns==1.2.0
# azure-mgmt-eventgrid==0.4.0
# azure-mgmt-iothub==0.4.0
# azure-mgmt-iothubprovisioningservices==0.1.0
# azure-mgmt-keyvault==0.40.0
# azure-mgmt-marketplaceordering==0.1.0
# azure-mgmt-monitor==0.4.0
# azure-mgmt-msi==0.1.0
# azure-mgmt-network==1.7.0
# azure-mgmt-nspkg==2.0.0
# azure-mgmt-rdbms==0.1.0
# azure-mgmt-recoveryservices==0.1.0
# azure-mgmt-recoveryservicesbackup==0.1.1
# azure-mgmt-redis==4.1.0
# azure-mgmt-reservations==0.1.0
# azure-mgmt-resource==1.2.1
# azure-mgmt-servicefabric==0.1.0
# azure-mgmt-sql==0.8.5
# azure-mgmt-storage==1.5.0
# azure-mgmt-trafficmanager==0.40.0
# azure-mgmt-web==0.35.0
# azure-multiapi-storage==0.2.0
# azure-nspkg==2.0.0
# azure-storage==0.34.3
# azureml==0.2.7
# Babel==2.5.0
# backports.functools-lru-cache==1.4
# backports.shutil-get-terminal-size==1.0.0
# bcrypt==3.1.4
# beautifier==0.3.3
# beautifulsoup4==4.6.0
# bitarray==0.8.1
# bkcharts==0.2
# blaze==0.11.3
# bleach==2.0.0
# bokeh==0.12.7
# boto==2.48.0
# boto3==1.4.8
# botocore==1.8.50
# Bottleneck==1.2.1
# bqplot==0.10.5
# brewer2mpl==1.4.1
# CacheControl==0.12.3
# certifi==2017.7.27.1
# cffi==1.10.0
# chardet==3.0.4
# click==6.7
# cloudpickle==0.4.0
# clyent==1.2.2
# cntk==2.0
# colorama==0.3.9
# conda==4.4.11
# conda-build==3.0.27
# conda-verify==2.0.0
# constantly==15.1.0
# contextlib2==0.5.5
# cryptography==2.0.3
# cycler==0.10.0
# Cython==0.26.1
# cytoolz==0.8.2
# dask==0.15.3
# datacleaner==0.1.5
# datashape==0.5.4
# decorator==4.1.2
# distributed==1.19.1
# docker-py==1.10.6
# docker-pycreds==0.2.2
# docutils==0.14
# Dora==0.0.2
# edward==1.3.5
# elasticsearch==6.1.1
# entrypoints==0.2.3
# et-xmlfile==1.0.1
# fastcache==1.0.2
# feedparser==5.2.1
# filelock==2.0.12
# Flask==0.12.2
# Flask-Cors==3.0.3
# ftfy==5.3.0
# future==0.16.0
# GDAL==2.2.2
# gevent==1.2.2
# ggplot==0.11.5
# glob2==0.5
# gmpy2==2.0.8
# graphviz==0.8.2
# greenlet==0.4.12
# grpcio==1.10.0
# gym==0.10.3
# h5py==2.7.1
# heapdict==1.0.0
# holoviews==1.8.3
# html5lib==0.999999999
# humanfriendly==4.8
# hyperlink==18.0.0
# idna==2.6
# imageio==2.2.0
# imagesize==0.7.1
# incremental==17.5.0
# ipaddress==1.0.19
# ipykernel==4.7.0
# ipython==6.2.1
# ipython-genutils==0.2.0
# ipywidgets==7.0.0b7
# isodate==0.6.0
# isort==4.2.15
# itsdangerous==0.24
# jdcal==1.3
# jedi==0.10.2
# Jinja2==2.9.6
# jmespath==0.9.3
# joblib==0.11
# jsonschema==2.6.0
# jupyter-client==5.1.0
# jupyter-console==5.2.0
# jupyter-core==4.4.0
# jupyterlab==0.27.0
# jupyterlab-launcher==0.4.0
# kafka-python==1.4.1
# kazoo==2.4.0
# Keras==2.1.4
# keyring==11.0.0
# klein==17.10.0
# knack==0.3.1
# lazy-object-proxy==1.3.1
# line-profiler==2.1.2
# llvmlite==0.20.0
# locket==0.2.0
# lockfile==0.12.2
# luigi==2.7.2
# lxml==4.1.0
# MarkupSafe==1.0
# matplotlib==2.1.1
# mccabe==0.6.1
# memory-profiler==0.52.0
# mistune==0.7.4
# mock==2.0.0
# mpmath==0.19
# msgpack-python==0.4.8
# msrest==0.4.27
# msrestazure==0.4.22
# multipledispatch==0.4.9
# natsort==5.1.0
# navigator-updater==0.1.0
# nbconvert==5.3.1
# nbformat==4.4.0
# networkx==1.11
# nltk==3.2.4
# nose==1.3.7
# notebook==5.0.0
# numba==0.35.0
# numexpr==2.6.2
# numpy==1.12.1
# numpydoc==0.7.0
# oauthlib==2.0.6
# odo==0.5.1
# olefile==0.44
# openfst==1.6.1
# openpyxl==2.4.8
# packaging==16.8
# pandas==0.20.3
# pandasql==0.7.3
# pandocfilters==1.4.2
# param==1.5.1
# paramiko==2.4.0
# partd==0.3.8
# path.py==10.3.1
# pathlib2==2.3.0
# patsy==0.4.1
# pbr==3.1.1
# pep8==1.7.0
# pexpect==4.2.1
# phonenumbers==8.9.1
# pickleshare==0.7.4
# Pillow==4.3.0
# pkginfo==1.4.1
# plotly==2.4.1
# ply==3.10
# prettypandas==0.0.3
# prompt-toolkit==1.0.15
# protobuf==3.4.1
# psutil==5.4.0
# psycopg2==2.7.1
# ptyprocess==0.5.2
# py==1.4.34
# pyang==1.7.4
# pyasn1==0.4.2
# pyasn1-modules==0.2.1
# pycodestyle==2.3.1
# pycosat==0.6.3
# pycparser==2.18
# pycrypto==2.6.1
# pycurl==7.43.0
# pydocumentdb==2.3.1
# pydot==1.2.4
# pyflakes==1.6.0
# PyGithub==1.37
# pyglet==1.3.1
# Pygments==2.2.0
# PyJWT==1.6.0
# pykafka==2.7.0
# pylint==1.7.4
# pymc==2.3.6
# pymc3==3.3
# pymongo==3.4.0
# Pympler==0.5
# pymssql==2.1.1
# PyMySQL==0.7.9
# PyNaCl==1.2.1
# pyodbc==3.1.1
# pyOpenSSL==17.2.0
# pypachy==0.1.5
# pyparsing==2.2.0
# pyprof2calltree==1.4.3
# PySocks==1.6.7
# pytest==3.2.1
# python-daemon==2.1.2
# python-dateutil==2.6.1
# pytz==2017.2
# PyWavelets==0.5.2
# PyYAML==3.12
# pyzmq==16.0.2
# QtAwesome==0.4.4
# qtconsole==4.3.1
# QtPy==1.3.1
# readline==6.2.4.1
# requests==2.18.4
# requests-oauthlib==0.8.0
# rope==0.10.5
# rpy2==2.9.2
# ruamel-yaml==0.11.14
# s3transfer==0.1.13
# scikit-bio==0.5.1
# scikit-image==0.13.0
# scikit-learn==0.19.1
# scipy==0.19.1
# scp==0.10.2
# scrubadub==1.2.0
# seaborn==0.8
# SecretStorage==2.3.1
# service-identity==17.0.0
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.11.0
# sklearn==0.0
# snakeviz==0.4.2
# snowballstemmer==1.2.1
# sortedcollections==0.5.3
# sortedcontainers==1.5.7
# Sphinx==1.6.3
# sphinxcontrib-websupport==1.0.1
# spyder==3.2.4
# SQLAlchemy==1.1.13
# sshtunnel==0.1.3
# statsmodels==0.8.0
# sympy==1.1.1
# tables==3.4.2
# tabulate==0.7.7
# tblib==1.3.2
# tensorflow==1.1.0
# terminado==0.6
# testpath==0.3.1
# textblob==0.10.0
# Theano==1.0.1
# toolz==0.8.2
# torch==0.3.1.post2
# torchvision==0.1.9
# tornado==4.5.2
# tqdm==4.19.6
# traitlets==4.3.2
# traittypes==0.0.6
# treq==17.8.0
# Twisted==17.9.0
# typing==3.6.2
# unicodecsv==0.14.1
# update-checker==0.16
# urllib3==1.22
# vega==0.4.4
# vsts-cd-manager==1.0.1
# wcwidth==0.1.7
# webencodings==0.5.1
# websocket-client==0.47.0
# Werkzeug==0.12.2
# Whoosh==2.7.4
# widgetsnbextension==3.0.0
# word2vec==0.9.2
# wrapt==1.10.11
# xlrd==1.1.0
# XlsxWriter==1.0.2
# xlwt==1.3.0
# xmltodict==0.11.0
# zict==0.1.3
# zope.interface==4.4.3
# You are using pip version 9.0.1, however version 9.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
